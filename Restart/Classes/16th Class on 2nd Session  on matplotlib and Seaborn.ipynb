# %%
import seaborn  as sns

# %%
iris = sns.load_dataset('iris') # If we want to check the list of data sets present in the seaborn by default "https://github.com/mwaskom/seaborn-data"
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique() # To check the unique values in the data set column.
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
ax = iris.plot(figsize=(15,8),title='Irish Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods = 1000), columns=['value'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#                value
# 2019-06-07 -0.490059
# 2019-06-08 -0.302329
# 2019-06-09  2.015516
# 2019-06-10  0.159623
# 2019-06-11  0.983667

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07 -0.490059
# 2019-06-08 -0.792388
# 2019-06-09  1.223128
# 2019-06-10  1.382751
# 2019-06-11  2.366419

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07   -0.193273
# 2019-06-08    0.221735
# 2019-06-09    2.097366
# 2019-06-10    2.478446
# 2019-06-11    2.327870
# Freq: D, dtype: float64

# %%
ts.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
ts.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df = iris.drop(['species'],axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.iloc[0] # 1st Row Values
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df2 = titanic.groupby(['pclass']).count()
df2.head()
# Out:
#         survived  sex  age  sibsp  parch  fare  embarked  class  who  \
# pclass
# 1            216  216  186    216    216   216       214    216  216
# 2            184  184  173    184    184   184       184    184  184
# 3            491  491  355    491    491   491       491    491  491
#
#         adult_male  deck  embark_town  alive  alone
# pclass
# 1              216   175          214    216    216
# 2              184    16          184    184    184
# 3              491    12          491    491    491

# %%
df2[['sex','age']].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
df = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
df.head(10)
# Out:
#           a         b         c         d
# 0 -0.081924 -0.339170 -0.490636  0.769349
# 1 -1.482479 -0.533047  0.192471  0.401849
# 2 -1.461316  1.192662 -1.518791  1.851549
# 3  0.213499 -0.586490 -0.707638  0.279665
# 4 -1.590920  0.465418 -1.408736 -1.862277
# 5 -0.512081  2.610615  0.894520  0.171349
# 6 -2.040206  1.306929  0.042034  0.382245
# 7  0.106880  1.612014 -1.519048 -0.819697
# 8  0.620883 -0.172160 -1.442971  0.632763
# 9  0.303456  0.608534 -0.645273  1.272390

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False,bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=False,bins=50,orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist', stacked = True, bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'b', alpha = 0.3, figsize=(10,10)) # alpha is used for the transparence of the charts.
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'b'}
color
# Out:
# {'boxes': 'DarkGreen', 'whiskers': 'b'}

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c='orange')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', label = 'Length');
#df.plot.scatter(x = 'sepal_width', y = 'petal_width', label = 'Width', ax = ax, color = 'r')
#df.plot.scatter(x = 'sepal_width', y = 'petal_length', label = 'Width', ax = ax, color = 'g')

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length', c = 'sepal_width', s = 190) # s--> Solid Pixcel
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 8, C = 'sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (10,10),)
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
d = df.head(3).T # T will transpose the data frame values
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 10, autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='Pie Plot'>

# %%
from pandas.plotting import scatter_matrix ## We will study this in the stastical chapter

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'b')
plt.show()

# %%
ts.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df, 'sepal_width')
# Out:
# <AxesSubplot:>

# %%
ts.plot(style = 'r--', label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(legend = True, figsize = (10, 5), logy = True)
# Out:
# <AxesSubplot:>

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2
# 5           5.4          3.9           1.7          0.4
# 6           4.6          3.4           1.4          0.3
# 7           5.0          3.4           1.5          0.2
# 8           4.4          2.9           1.4          0.2
# 9           4.9          3.1           1.5          0.1

# %%
x = df.drop(['sepal_width', 'petal_width'], axis = 1)
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y = df.drop(['sepal_length', 'petal_length'], axis = 1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=True, ax = ax)
# Out:
# <AxesSubplot:>

# %%
ax = x.plot()
y.plot(figsize = (16,10), secondary_y=False, ax = ax)
# Out:
# <AxesSubplot:>

# %%
x.plot(figsize=(10,5), x_compat = True)
# Out:
# <AxesSubplot:>

# %%
x.plot(figsize=(10,5), x_compat = False)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots = True) # Each features will be drawn in different chart.
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
plt.tight_layout()

# %%
pip install descartes
# Out:
# Requirement already satisfied: descartes in c:\users\bharat-pc\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\bharat-pc\anaconda3\lib\site-packages (from descartes) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (1.3.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\bharat-pc\anaconda3\lib\site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\bharat-pc\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from descartes import PolygonPatch

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\bharat-pc\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\bharat-pc\anaconda3\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\bharat-pc\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: importlib-metadata in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (4.11.3)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (21.4.0)
# Requirement already satisfied: click~=8.0 in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: certifi in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2021.10.8)
# Requirement already satisfied: setuptools in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (61.2.0)
# Requirement already satisfied: six in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\bharat-pc\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: colorama in c:\users\bharat-pc\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bharat-pc\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bharat-pc\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\bharat-pc\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas) (1.21.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\bharat-pc\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bharat-pc\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# %%
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
map_df
# Out:
#                                              geometry
# 0   POLYGON ((516401.600 160201.800, 516407.300 16...
# 1   POLYGON ((535009.200 159504.700, 535005.500 15...
# 2   POLYGON ((540373.600 157530.400, 540361.200 15...
# 3   POLYGON ((521975.800 178100.000, 521967.700 17...
# 4   POLYGON ((510253.500 182881.600, 510249.900 18...
# 5   POLYGON ((549893.900 181459.800, 549894.600 18...
# 6   POLYGON ((510599.800 191689.500, 510615.200 19...
# 7   POLYGON ((510599.800 191689.500, 510660.000 19...
# 8   POLYGON ((525201.000 182512.600, 525181.500 18...
# 9   POLYGON ((524579.900 198355.200, 524594.300 19...
# 10  POLYGON ((530046.800 177893.400, 530048.400 17...
# 11  POLYGON ((531335.600 180529.500, 531337.700 18...
# 12  POLYGON ((536691.000 178958.600, 536691.900 17...
# 13  MULTIPOLYGON (((537238.700 178137.700, 537242....
# 14  POLYGON ((547226.200 181299.300, 547320.900 18...
# 15  POLYGON ((531023.500 200933.600, 531039.900 20...
# 16  POLYGON ((539923.100 191863.100, 539928.100 19...
# 17  POLYGON ((543595.500 184832.800, 543577.100 18...
# 18  POLYGON ((528552.300 159658.100, 528399.700 15...
# 19  POLYGON ((516677.500 175383.800, 516678.600 17...
# 20  POLYGON ((529906.200 167417.300, 529902.200 16...
# 21  POLYGON ((523489.600 176224.800, 523500.600 17...
# 22  POLYGON ((521975.800 178100.000, 521973.000 17...
# 23  POLYGON ((526219.700 176948.000, 526208.800 17...
# 24  POLYGON ((528549.500 177903.800, 528542.600 17...
# 25  POLYGON ((528840.200 187217.800, 528834.600 18...
# 26  POLYGON ((533387.600 180516.400, 533389.800 18...
# 27  POLYGON ((529153.600 185861.400, 529144.800 18...
# 28  POLYGON ((531928.400 187801.500, 531935.700 18...
# 29  POLYGON ((531928.400 187801.500, 531919.200 18...
# 30  MULTIPOLYGON (((544065.000 183254.100, 544062....
# 31  MULTIPOLYGON (((543905.400 183199.100, 543905....
# 32  POLYGON ((531145.100 180782.100, 531143.800 18...

# %% [markdown]
# # Seaborn

# %% [markdown]
# # Visualizing statistical relationships
#
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.
#
# ### 1. Numerical Data Ploting
# - relplot()
# - scatterplot()
# - lineplot()
#
# ### 2. Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# - etc...
#
# ### 3. Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()
#
# ### 4. Linear Regression and Relationship
# - regplot()
# - lmplot()
#
# ### 5. Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(style = 'darkgrid')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['size'].head()
# Out:
# 0    2
# 1    3
# 2    3
# 3    2
# 4    4
# Name: size, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips) #Relation plot

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker') #Relation plot

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time') #Relation plot

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='sex') #Relation plot

# %%
sns.relplot(x='total_bill',y='tip',data=tips,style='size') #Relation plot

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='size') #Relation plot

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time',size='size') #Relation plot

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size')

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0 -0.538694
# 1     1 -1.077165
# 2     2 -0.382953
# 3     3 -0.258618
# 4     4  0.361149

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
df = pd.DataFrame(randn(500, 2).cumsum(axis = 0), columns = ['time', 'value'])
df.head()
# Out:
#        time     value
# 0 -0.527170  0.552372
# 1 -0.648362  0.390569
# 2 -0.307669  0.374170
# 3  0.527843 -0.177479
# 4  2.020496 -1.069051

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df, sort = True)

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, ci = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', estimator = None, kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', kind = 'line', data = fmri, markers = True, dashes = False)

# %%
sns.relplot(x = 'timepoint', y = 'signal', hue = 'event', style = 'event', kind = 'line', data = fmri)

# %%
df = pd.DataFrame(dict(time = pd.date_range('2019-06-02', periods = 500), value = randn(500).cumsum()))
df.head()
# Out:
#         time     value
# 0 2019-06-02 -0.188355
# 1 2019-06-03  0.662083
# 2 2019-06-04  1.659653
# 3 2019-06-05  0.664125
# 4 2019-06-06 -0.186278

# %%
g = sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', data = tips)

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips, col_wrap=3, height=3)

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'smoker', data = tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y  = 'signal', style = 'event', hue = 'region', data = fmri, markers = True, ci = 68, err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>
