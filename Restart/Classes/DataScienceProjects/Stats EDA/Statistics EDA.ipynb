# %% [markdown]
# ### Stats Concepts Understanding

# %%
import pandas as pd

# %%
df=pd.read_csv('weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
#If I wanted to check the column details of the dataset, Then use the info Function.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender']=='Male'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
df[df['Gender']=='Male']
# Out:
#      Gender     Height      Weight
# 0      Male  73.847017  241.893563
# 1      Male  68.781904  162.310473
# 2      Male  74.110105  212.740856
# 3      Male  71.730978  220.042470
# 4      Male  69.881796  206.349801
# ...     ...        ...         ...
# 4995   Male  68.860062  177.131052
# 4996   Male  68.973423  159.285228
# 4997   Male  67.013795  199.195400
# 4998   Male  71.557718  185.905909
# 4999   Male  70.351880  198.903012
#
# [5000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df[df["Gender"]=="Male"]
# Out:
#      Gender     Height      Weight
# 0      Male  73.847017  241.893563
# 1      Male  68.781904  162.310473
# 2      Male  74.110105  212.740856
# 3      Male  71.730978  220.042470
# 4      Male  69.881796  206.349801
# ...     ...        ...         ...
# 4995   Male  68.860062  177.131052
# 4996   Male  68.973423  159.285228
# 4997   Male  67.013795  199.195400
# 4998   Male  71.557718  185.905909
# 4999   Male  70.351880  198.903012
#
# [5000 rows x 3 columns]

# %%
import numpy as np
data_male=df[df["Gender"]=="Male"]
data_female=df[df["Gender"]=="Female"]

# %%
data_male
# Out:
#      Gender     Height      Weight
# 0      Male  73.847017  241.893563
# 1      Male  68.781904  162.310473
# 2      Male  74.110105  212.740856
# 3      Male  71.730978  220.042470
# 4      Male  69.881796  206.349801
# ...     ...        ...         ...
# 4995   Male  68.860062  177.131052
# 4996   Male  68.973423  159.285228
# 4997   Male  67.013795  199.195400
# 4998   Male  71.557718  185.905909
# 4999   Male  70.351880  198.903012
#
# [5000 rows x 3 columns]

# %%
data_female
# Out:
#       Gender     Height      Weight
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [5000 rows x 3 columns]

# %% [markdown]
# ### Univariate,Bivariate,Multivariate Analysis

# %%
plt.plot(data_male["Height"],np.zeros_like(data_male["Height"]),'bo',label="Male")
plt.plot(data_female["Height"],np.zeros_like(data_female["Height"]),'ro',label="Female")
plt.show()

# %%
import seaborn as sns

# %%
sns.displot(data_female["Height"],kde=False)

# %%
sns.histplot(data_female["Height"],kde=True)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Count'>

# %%
sns.FacetGrid(df,hue="Gender",size=8).map(sns.distplot,"Height").add_legend()
# Out:
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(df,hue="Gender",size=8).map(sns.distplot,"Weight").add_legend()
# Out:
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_male['Weight'],kde=False)
# Out:
# C:\Users\Bharat-PC\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight'>

# %%
## Percentiles
print("25 percentile value is ",np.percentile(data_male['Weight'],25))
print("50 percentile value is ",np.percentile(data_male['Weight'],50))
print("75 percentile value is ",np.percentile(data_male['Weight'],75))
print("90 percentile value is ",np.percentile(data_male['Weight'],90))
# Out:
# 25 percentile value is  173.88776733421798
# 50 percentile value is  187.033546088862
# 75 percentile value is  200.35780180200075
# 90 percentile value is  211.7686848861595

# %% [markdown]
# ### Cumulative Density Function

# %%
# getting data of the histogram 
count, bins_count = np.histogram(data_male['Weight'], bins=10) 
  
# finding the PDF of the histogram using count values 
pdf = count / sum(count) 
  
# using numpy np.cumsum to calculate the CDF 
# We can also find using the PDF values by looping and adding 
cdf = np.cumsum(pdf) 
  
# plotting PDF and CDF 
plt.plot(bins_count[1:], pdf, color="red", label="PDF") 
plt.plot(bins_count[1:], cdf, label="CDF") 
plt.legend()

# %%
# getting data of the histogram 
count, bins_count = np.histogram(data_male['Height'], bins=10) 
  
# finding the PDF of the histogram using count values 
pdf = count / sum(count) 
  
# using numpy np.cumsum to calculate the CDF 
# We can also find using the PDF values by looping and adding 
cdf = np.cumsum(pdf) 
  
# plotting PDF and CDF 
plt.plot(bins_count[1:], pdf, color="green", label="PDF") 
plt.plot(bins_count[1:], cdf, label="CDF") 
plt.legend()

# %% [markdown]
# ### Univariate, BiVariate And Multivariate Analysis

# %%
plt.scatter(data_male['Height'],data_male['Weight'])
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %%
sns.pairplot(df,hue="Gender")

# %%
sns.jointplot(x="Weight",y="Height",data=df,kind="kde")

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
df.corr(method='spearman')
# Out:
#           Height    Weight
# Height  1.000000  0.925708
# Weight  0.925708  1.000000

# %% [markdown]
# ### Covariance, Pearson Correlation, Spearman Rank Correlation Coefficient

# %%
df_iris=sns.load_dataset('iris')
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df_iris,hue='species')

# %%
df_iris.corr(method='spearman')
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.166778      0.881898     0.834289
# sepal_width      -0.166778     1.000000     -0.309635    -0.289032
# petal_length      0.881898    -0.309635      1.000000     0.937667
# petal_width       0.834289    -0.289032      0.937667     1.000000
