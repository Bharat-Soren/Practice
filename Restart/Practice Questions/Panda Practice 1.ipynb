# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv'
df = pd.read_csv(url)
df.head(10)
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
# 5   Life expectancy at birth (years)      Published  2000
# 6  Life expectancy at age 60 (years)      Published  1990
# 7  Life expectancy at age 60 (years)      Published  2012
# 8   Life expectancy at birth (years)      Published  2012
# 9   Life expectancy at birth (years)      Published  2000
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# ...

# %%
url1 = 'https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv'
df1 = pd.read_csv(url1)
df1.head(10)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
# 5  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310107    10 -9999 -9999     0
# 6  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999    11
# 7  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999   -22
# 8  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999     0
# 9  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999    22
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# ...

# %% [markdown]
# ##### 1. Get the Metadata from the above files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Indicator                4656 non-null   object
#  1   PUBLISH STATES           4656 non-null   object
#  2   Year                     4656 non-null   int64
#  3   WHO region               4656 non-null   object
#  4   World Bank income group  4656 non-null   object
#  5   Country                  4656 non-null   object
#  6   Sex                      4656 non-null   object
#  7   Display Value            4656 non-null   int64
#  8   Numeric                  4656 non-null   float64
#  9   Low                      0 non-null      float64
#  10  High                     0 non-null      float64
#  11  Comments                 0 non-null      float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   STATION       117208 non-null  object
#  1   STATION_NAME  117208 non-null  object
#  2   DATE          117208 non-null  int64
#  3   PRCP          117208 non-null  int64
#  4   SNWD          117208 non-null  int64
#  5   SNOW          117208 non-null  int64
#  6   TMAX          117208 non-null  int64
#  7   TMIN          117208 non-null  int64
#  8   WDFG          117208 non-null  int64
#  9   PGTM          117208 non-null  int64
#  10  WSFG          117208 non-null  int64
#  11  WT09          117208 non-null  int64
#  12  WT07          117208 non-null  int64
#  13  WT01          117208 non-null  int64
#  14  WT06          117208 non-null  int64
#  15  WT05          117208 non-null  int64
#  16  WT04          117208 non-null  int64
#  17  WT16          117208 non-null  int64
# ...

# %%
df.shape[0]  # Number Of Records
# Out:
# 4656

# %% [markdown]
# #### 2. Get the row names from the above files.
# Expected Output:

# %%
df.index.to_numpy()
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1.index.to_numpy()
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# #### 3. Change the column name from any of the above file.

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df.rename(columns={'Indicator':'Indicator_Id'}) # Temporary Renaming the DF column name
# Out:
#                                          Indicator_Id PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# ...                                               ...            ...   ...
# 4651  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4652  Healthy life expectancy (HALE) at birth (years)      Published  2012
# 4653  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4654  Healthy life expectancy (HALE) at birth (years)      Published  2000
# 4655  Healthy life expectancy (HALE) at birth (years)      Published  2012
#
# ...

# %%
df.head(10)
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
# 5   Life expectancy at birth (years)      Published  2000
# 6  Life expectancy at age 60 (years)      Published  1990
# 7  Life expectancy at age 60 (years)      Published  2012
# 8   Life expectancy at birth (years)      Published  2012
# 9   Life expectancy at birth (years)      Published  2000
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# ...

# %% [markdown]
# #### 4. Change the column name from any of the above file and store the changes made permanently.

# %%
df.rename(columns={'Indicator':'Indicator_id'},inplace = True)

# %%
df.head()
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ##### 5. Change the names of multiple columns.
# Expected Output:

# %%
df.rename(columns = {'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},inplace= True)

# %%
df.head()
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ##### 6. Arrange values of a particular column in ascending order.

# %%
df.sort_values(by = ['Year'],ascending= True).head(10)
# Out:
#                            Indicator_id Publication Status  Year  \
# 0      Life expectancy at birth (years)          Published  1990
# 1270   Life expectancy at birth (years)          Published  1990
# 3193   Life expectancy at birth (years)          Published  1990
# 3194   Life expectancy at birth (years)          Published  1990
# 3197  Life expectancy at age 60 (years)          Published  1990
# 1264   Life expectancy at birth (years)          Published  1990
# 3199  Life expectancy at age 60 (years)          Published  1990
# 1262  Life expectancy at age 60 (years)          Published  1990
# 1259   Life expectancy at birth (years)          Published  1990
# 3203  Life expectancy at age 60 (years)          Published  1990
#
#            WHO Region World Bank income group              Country  \
# 0              Europe             High-income              Andorra
# 1270           Europe             High-income              Germany
# ...

# %% [markdown]
# ##### 7. Arrange multiple column values in ascending order.

# %%
df[['Indicator_id','Country','Year','WHO Region','Publication Status']].sort_values(by=['Indicator_id','Country','Year','WHO Region','Publication Status']).head(3)
# Out:
#                                          Indicator_id      Country  Year  \
# 2798  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 3363  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
# 4456  Healthy life expectancy (HALE) at birth (years)  Afghanistan  2000
#
#                  WHO Region Publication Status
# 2798  Eastern Mediterranean          Published
# 3363  Eastern Mediterranean          Published
# 4456  Eastern Mediterranean          Published

# %% [markdown]
# ##### 8. Make country as the first column of the dataframe.
# Expected Output:

# %%
df.head()
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
first_column = df.pop('Country')

df.insert(0,'Country',first_column)
df.head()
# Out:
#                 Country                       Indicator_id Publication Status  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %%
df.describe()
# Out:
#               Year  Display Value      Numeric  Low  High  Comments
# count  4656.000000    4656.000000  4656.000000  0.0   0.0       0.0
# mean   2002.000000      47.194588    47.194588  NaN   NaN       NaN
# std       8.661184      23.843194    23.843194  NaN   NaN       NaN
# min    1990.000000      11.000000    11.000000  NaN   NaN       NaN
# 25%    1997.500000      20.000000    20.000000  NaN   NaN       NaN
# 50%    2000.000000      55.000000    55.000000  NaN   NaN       NaN
# 75%    2012.000000      68.000000    68.000000  NaN   NaN       NaN
# max    2012.000000      87.000000    87.000000  NaN   NaN       NaN

# %% [markdown]
# ##### 9. Get the column array using a variable
# Expected Output:

# %%
df['Country'].to_numpy()
# Out:
# array(['Andorra', 'Andorra', 'Andorra', ..., 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %% [markdown]
# ##### 10. Get the subset rows 11, 24, 37
# Expected Output:

# %%
df.loc[[11,24,37]]
# Out:
#               Country                       Indicator_id Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %% [markdown]
# ##### 11. Get the subset rows excluding 5, 12, 23, and 56
# Expected Output:

# %%
dftmp = df
dftmp.drop([1,5,12,23,56])
# Out:
#                    Country                                     Indicator_id  \
# 0                  Andorra                 Life expectancy at birth (years)
# 2                  Andorra                Life expectancy at age 60 (years)
# 3                  Andorra                Life expectancy at age 60 (years)
# 4     United Arab Emirates                 Life expectancy at birth (years)
# 6      Antigua and Barbuda                Life expectancy at age 60 (years)
# ...                    ...                                              ...
# 4651                 Samoa  Healthy life expectancy (HALE) at birth (years)
# 4652                 Yemen  Healthy life expectancy (HALE) at birth (years)
# 4653          South Africa  Healthy life expectancy (HALE) at birth (years)
# 4654                Zambia  Healthy life expectancy (HALE) at birth (years)
# 4655              Zimbabwe  Healthy life expectancy (HALE) at birth (years)
#
# ...

# %%
dftmp[~dftmp.index.isin([1,5,12,23,56])]
# Out:
#                    Country                                     Indicator_id  \
# 0                  Andorra                 Life expectancy at birth (years)
# 2                  Andorra                Life expectancy at age 60 (years)
# 3                  Andorra                Life expectancy at age 60 (years)
# 4     United Arab Emirates                 Life expectancy at birth (years)
# 6      Antigua and Barbuda                Life expectancy at age 60 (years)
# ...                    ...                                              ...
# 4651                 Samoa  Healthy life expectancy (HALE) at birth (years)
# 4652                 Yemen  Healthy life expectancy (HALE) at birth (years)
# 4653          South Africa  Healthy life expectancy (HALE) at birth (years)
# 4654                Zambia  Healthy life expectancy (HALE) at birth (years)
# 4655              Zimbabwe  Healthy life expectancy (HALE) at birth (years)
#
# ...

# %% [markdown]
# ##### 12. Load datasets from CSV

# %%
users_url = 'https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv'
users = pd.read_csv(users_url)

sessions_url = 'https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv'
sessions = pd.read_csv(sessions_url)

products_url = 'https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv'
products = pd.read_csv(products_url)

transactions_url = 'https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv'
transactions = pd.read_csv(transactions_url)

# %%
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# ##### 12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
pd.merge(transactions,users,how='left',on=['UserID'])
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# ##### 13. Which transactions have a UserID not in users?
# Expected Output:

# %%
tmp = pd.merge(transactions,users,how='left')
np.where(tmp['User'] isnull )
# Out:
#   Input In [118]
#     np.where(tmp['User'] isnull)
#                          ^
# SyntaxError: invalid syntax
